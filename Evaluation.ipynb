# %% [markdown]
# <a href="https://colab.research.google.com/github/ani-101/Online_Meeting_Summarizer/blob/main/Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
nltk.download('stopwords')
from nltk import sent_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## Eg 1

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


text1 = ''' Long ago there was an honest woodcutter, there lived a woodcutter in a small village. He was sincere in his work and very honest. Every day, he set out into the nearby forest to cut trees. He brought the woods back into the village and sold them out to a merchant and earn his money. He earned just about enough to make a living, but he was satisfied with his simple living. One day, while cutting a tree near a river, his axe slipped out of his hand and fell into the river. The river was so deep, he could not even think to retrieve it on his own. He only had one axe which was gone into the river. He became a very worried thinking how he will be able to earn his living now! He was very sad and prayed to the Goddess. He prayed sincerely so the Goddess appeared in front of him and asked, “What is the problem, my son?” The woodcutter explained the problem and requested the Goddess to get his axe back. The Goddess put her hand deep into the river and took out a silver axe and asked, “Is this your axe?” The Woodcutter looked at the axe and said “No”. So the Goddess put her hand back deep into the water again and showed a golden axe and asked, “Is this your axe?”  The woodcutter looked at the axe and said “No”. The Goddess said, “Take a look again Son, this is a very valuable golden axe, are you sure this is not yours?” The woodcutter said, “No, It’s not mine. I can’t cut the trees with a golden axe. It’s not useful for me”. The Goddess smiled and finally put her hand into the water again and took out his iron axe and asked, “Is this your axe?” To this, the woodcutter said, “Yes! This is mine!  Thank you!” The Goddess was very impressed with his honesty so she gave him his iron axe and also other two axes as a reward for his honesty.'''

# Input text - to summarize
#text = "story.txt"
#sentences =  read_article(text)
# Tokenizing the text
stopWords = set(stopwords.words("english"))
words = word_tokenize(text1)

# Creating a frequency table to keep the
# score of each word

freqTable = dict()
for word in words:
	word = word.lower()
	if word in stopWords:
		continue
	if word in freqTable:
		freqTable[word] += 1
	else:
		freqTable[word] = 1
sentences = sent_tokenize(text1)
sentenceValue = dict()

for sentence in sentences:
	for word, freq in freqTable.items():
		if word in sentence.lower():
			if sentence in sentenceValue:
				sentenceValue[sentence] += freq
			else:
				sentenceValue[sentence] = freq



sumValues = 0
for sentence in sentenceValue:
	sumValues += sentenceValue[sentence]

# Average value of a sentence from the original text

average = int(sumValues / len(sentenceValue))

# Storing sentences into our summary.
summary = ''
for sentence in sentences:
	if (sentence in sentenceValue) and (sentenceValue[sentence] > (1.2 * average)):
		summary += " " + sentence
print(summary)
# Out:
#  He prayed sincerely so the Goddess appeared in front of him and asked, “What is the problem, my son?” The woodcutter explained the problem and requested the Goddess to get his axe back. The Goddess put her hand deep into the river and took out a silver axe and asked, “Is this your axe?” The Woodcutter looked at the axe and said “No”. So the Goddess put her hand back deep into the water again and showed a golden axe and asked, “Is this your axe?”  The woodcutter looked at the axe and said “No”. The Goddess said, “Take a look again Son, this is a very valuable golden axe, are you sure this is not yours?” The woodcutter said, “No, It’s not mine. The Goddess smiled and finally put her hand into the water again and took out his iron axe and asked, “Is this your axe?” To this, the woodcutter said, “Yes!

# %%
! pip install datasets transformers[sentencepiece]
! pip install nltk rouge_score
from datasets import load_metric
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.8/462.8 KB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 85.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.0/132.0 KB 17.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.3/190.3 KB 24.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 KB 28.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 87.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 70.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 18.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ...

# %%
rouge = load_metric("rouge")
predictions = ["He prayed sincerely so the Goddess appeared in front of him and asked, “What is the problem, my son?” The woodcutter explained the problem and requested the Goddess to get his axe back. The Goddess put her hand deep into the river and took out a silver axe and asked, “Is this your axe?” The Woodcutter looked at the axe and said “No”. So the Goddess put her hand back deep into the water again and showed a golden axe and asked, “Is this your axe?”  The woodcutter looked at the axe and said “No”. The Goddess said, “Take a look again Son, this is a very valuable golden axe, are you sure this is not yours?” The woodcutter said, “No, It’s not mine. The Goddess smiled and finally put her hand into the water again and took out his iron axe and asked, “Is this your axe?” To this, the woodcutter said, “Yes!"]
references = ["The story of honest woodcutter is about that everyone should be honest. In the begining, a woodcutter fell his axe in the river. This axe is the most important thing to him. So he prayed to the river God. River God show three axe to him. One is the gold axe, the other is silver axe, but this woodcutter does't accept it until God shows the axe which woodcutter had lost. River God is pleaswith woodcutter's honesty. He give the gold axe and the silver axe also to him. That tell us that honesty is the best policy."]
rouge.compute(predictions=predictions, references=references)
# Out:
# <ipython-input-5-19f8d3760751>:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = load_metric("rouge")
# ...
# {'rouge1': AggregateScore(low=Score(precision=0.3032258064516129, recall=0.47, fmeasure=0.3686274509803921), mid=Score(precision=0.3032258064516129, recall=0.47, fmeasure=0.3686274509803921), high=Score(precision=0.3032258064516129, recall=0.47, fmeasure=0.3686274509803921)),
#  'rouge2': AggregateScore(low=Score(precision=0.05844155844155844, recall=0.09090909090909091, fmeasure=0.07114624505928854), mid=Score(precision=0.05844155844155844, recall=0.09090909090909091, fmeasure=0.07114624505928854), high=Score(precision=0.05844155844155844, recall=0.09090909090909091, fmeasure=0.07114624505928854)),
# ...

# %% [markdown]
# # Eg 2

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


text1 = """Once upon a time, there was a young adventurer named Jack who had always dreamed of discovering a lost city filled with treasure and riches. He had heard tales of a place called the Lost City, which was said to be located deep in the heart of the jungle and guarded by dangerous beasts and traps. Determined to make his dream a reality, Jack set out on a journey to find the Lost City. He traveled through treacherous terrain, facing countless challenges along the way, but he never gave up. He finally arrived at the entrance to the Lost City and was met by a fearsome dragon.Jack stood his ground, knowing that the treasure of the Lost City was within reach. He battled the dragon and emerged victorious, but not before discovering that the dragon was guarding something even more valuable than treasure - a map that led to a secret underground chamber filled with knowledge and wisdom. Excited by his discovery, Jack explored the chamber and learned all that he could. He left the Lost City a richer man, not just in terms of wealth, but in knowledge and experience as well. He realized that sometimes, the things that are truly valuable in life cannot be found in a treasure chest."""
# Input text - to summarize
#text = "story.txt"
#sentences =  read_article(text)
# Tokenizing the text
stopWords = set(stopwords.words("english"))
words = word_tokenize(text1)

# Creating a frequency table to keep the
# score of each word

freqTable = dict()
for word in words:
	word = word.lower()
	if word in stopWords:
		continue
	if word in freqTable:
		freqTable[word] += 1
	else:
		freqTable[word] = 1
sentences = sent_tokenize(text1)
sentenceValue = dict()

for sentence in sentences:
	for word, freq in freqTable.items():
		if word in sentence.lower():
			if sentence in sentenceValue:
				sentenceValue[sentence] += freq
			else:
				sentenceValue[sentence] = freq



sumValues = 0
for sentence in sentenceValue:
	sumValues += sentenceValue[sentence]

# Average value of a sentence from the original text

average = int(sumValues / len(sentenceValue))

# Storing sentences into our summary.
summary = ''
for sentence in sentences:
	if (sentence in sentenceValue) and (sentenceValue[sentence] > (1.2 * average)):
		summary += " " + sentence
print(summary)
# Out:
#  Once upon a time, there was a young adventurer named Jack who had always dreamed of discovering a lost city filled with treasure and riches. He finally arrived at the entrance to the Lost City and was met by a fearsome dragon.Jack stood his ground, knowing that the treasure of the Lost City was within reach.

# %%
rouge = load_metric("rouge")
predictions = [" Once upon a time, there was a young adventurer named Jack who had always dreamed of discovering a lost city filled with treasure and riches. He finally arrived at the entrance to the Lost City and was met by a fearsome dragon.Jack stood his ground, knowing that the treasure of the Lost City was within reach."]
references = ["Jack is a young adventurer who sets out to find the Lost City, a place said to be filled with treasure. He faces numerous challenges along the way and eventually defeats a dragon guarding the entrance to the city. He discovers that the dragon was guarding a map to a secret chamber filled with knowledge and wisdom, which he explores and gains valuable insights. He realizes that the things that are truly valuable in life cannot be found in a treasure chest."]
rouge.compute(predictions=predictions, references=references)
# Out:
# <ipython-input-5-53a9d990c651>:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = load_metric("rouge")
# ...
# {'rouge1': AggregateScore(low=Score(precision=0.47368421052631576, recall=0.32926829268292684, fmeasure=0.3884892086330935), mid=Score(precision=0.47368421052631576, recall=0.32926829268292684, fmeasure=0.3884892086330935), high=Score(precision=0.47368421052631576, recall=0.32926829268292684, fmeasure=0.3884892086330935)),
#  'rouge2': AggregateScore(low=Score(precision=0.17857142857142858, recall=0.12345679012345678, fmeasure=0.145985401459854), mid=Score(precision=0.17857142857142858, recall=0.12345679012345678, fmeasure=0.145985401459854), high=Score(precision=0.17857142857142858, recall=0.12345679012345678, fmeasure=0.145985401459854)),
# ...

# %% [markdown]
# # Eg 3

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


text1 = """Once upon a time, there was a poor little girl who had to sell matches on the street on New Year's Eve. She was so cold that she could barely hold the matches, and her feet were numb from the snow. The little girl had no home to go to and no one to take care of her. As she walked the streets, she struck one of her matches to keep warm. The sudden light revealed a vision of a warm and cozy home, with a table set for a feast and a fire burning in the hearth. The little girl was filled with longing, but the vision disappeared as quickly as it had appeared. She struck another match and saw another beautiful vision, this time of a Christmas tree surrounded by happy children. One by one, the little girl struck all of her matches, each time seeing a vision of happiness and warmth that she would never experience. Finally, she struck her last match, and as the flame flickered out, the little girl lay down in the snow, exhausted and hopeless. The next morning, the little girl was found dead in the snow, but she was smiling, as if she had found peace in her final moments. It was said that the little match girl had gone to heaven, where she was surrounded by warmth and love for all eternity."""
# Input text - to summarize
#text = "story.txt"
#sentences =  read_article(text)
# Tokenizing the text
stopWords = set(stopwords.words("english"))
words = word_tokenize(text1)

# Creating a frequency table to keep the
# score of each word

freqTable = dict()
for word in words:
	word = word.lower()
	if word in stopWords:
		continue
	if word in freqTable:
		freqTable[word] += 1
	else:
		freqTable[word] = 1
sentences = sent_tokenize(text1)
sentenceValue = dict()

for sentence in sentences:
	for word, freq in freqTable.items():
		if word in sentence.lower():
			if sentence in sentenceValue:
				sentenceValue[sentence] += freq
			else:
				sentenceValue[sentence] = freq



sumValues = 0
for sentence in sentenceValue:
	sumValues += sentenceValue[sentence]

# Average value of a sentence from the original text

average = int(sumValues / len(sentenceValue))

# Storing sentences into our summary.
summary = ''
for sentence in sentences:
	if (sentence in sentenceValue) and (sentenceValue[sentence] > (1.2 * average)):
		summary += " " + sentence
print(summary)
# Out:
#  One by one, the little girl struck all of her matches, each time seeing a vision of happiness and warmth that she would never experience.

# %%
rouge = load_metric("rouge")
predictions = ["One by one, the little girl struck all of her matches, each time seeing a vision of happiness and warmth that she would never experience."]
references = ["The Little Match Girl is a poor girl who sells matches on the street on New Year's Eve. She is so cold and lonely that she strikes her matches to keep warm, each time seeing a vision of happiness and warmth. After striking her last match, she lies down in the snow and dies, but is said to have gone to heaven where she is surrounded by warmth and love."]
rouge.compute(predictions=predictions, references=references)
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.68, recall=0.23943661971830985, fmeasure=0.35416666666666663), mid=Score(precision=0.68, recall=0.23943661971830985, fmeasure=0.35416666666666663), high=Score(precision=0.68, recall=0.23943661971830985, fmeasure=0.35416666666666663)),
#  'rouge2': AggregateScore(low=Score(precision=0.4583333333333333, recall=0.15714285714285714, fmeasure=0.23404255319148934), mid=Score(precision=0.4583333333333333, recall=0.15714285714285714, fmeasure=0.23404255319148934), high=Score(precision=0.4583333333333333, recall=0.15714285714285714, fmeasure=0.23404255319148934)),
#  'rougeL': AggregateScore(low=Score(precision=0.6, recall=0.2112676056338028, fmeasure=0.3125), mid=Score(precision=0.6, recall=0.2112676056338028, fmeasure=0.3125), high=Score(precision=0.6, recall=0.2112676056338028, fmeasure=0.3125)),
# ...

# %% [markdown]
# # Eg 4

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


text1 = """Once upon a time, there was a young girl named Sarah. Sarah lived in a small village and was known for her kindness and beauty. Despite her popularity, Sarah was a very humble person and always helped others in need.
One day, a wicked witch came to the village and cast a spell on all its residents, causing them to fall into a deep sleep. The only way to break the spell was to find a magical flower that grew in a dangerous forest, surrounded by fierce beasts and treacherous obstacles.
Sarah, being the brave and selfless person she was, set out on a journey to find the flower and break the spell. After facing numerous challenges, she finally found the flower and brought it back to the village. As she held the flower in her hand, the spell was broken, and everyone woke up from their sleep.
The villagers were grateful to Sarah for saving them, and the wicked witch was never seen or heard from again. From that day on, Sarah was hailed as a hero and her bravery and kindness were remembered for generations to come."""
# Input text - to summarize
#text = "story.txt"
#sentences =  read_article(text)
# Tokenizing the text
stopWords = set(stopwords.words("english"))
words = word_tokenize(text1)

# Creating a frequency table to keep the
# score of each word

freqTable = dict()
for word in words:
	word = word.lower()
	if word in stopWords:
		continue
	if word in freqTable:
		freqTable[word] += 1
	else:
		freqTable[word] = 1
sentences = sent_tokenize(text1)
sentenceValue = dict()

for sentence in sentences:
	for word, freq in freqTable.items():
		if word in sentence.lower():
			if sentence in sentenceValue:
				sentenceValue[sentence] += freq
			else:
				sentenceValue[sentence] = freq



sumValues = 0
for sentence in sentenceValue:
	sumValues += sentenceValue[sentence]

# Average value of a sentence from the original text

average = int(sumValues / len(sentenceValue))

# Storing sentences into our summary.
summary = ''
for sentence in sentences:
	if (sentence in sentenceValue) and (sentenceValue[sentence] > (1.2 * average)):
		summary += " " + sentence
print(summary)
# Out:
#  Sarah, being the brave and selfless person she was, set out on a journey to find the flower and break the spell.

# %%
rouge = load_metric("rouge")
predictions = [" Sarah, being the brave and selfless person she was, set out on a journey to find the flower and break the spell."]
references = ["The story is about a young girl named Sarah who sets out on a dangerous journey to save her village from a wicked witch's spell. Despite the challenges she faces, she finds a magical flower and breaks the spell, waking up all the residents of the village. Her bravery and kindness are remembered and celebrated by the villagers, and she is hailed as a hero."]
rouge.compute(predictions=predictions, references=references)
# Out:
# <ipython-input-7-98ad6d30dd32>:1: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   rouge = load_metric("rouge")
# ...
# {'rouge1': AggregateScore(low=Score(precision=0.6363636363636364, recall=0.21212121212121213, fmeasure=0.3181818181818182), mid=Score(precision=0.6363636363636364, recall=0.21212121212121213, fmeasure=0.3181818181818182), high=Score(precision=0.6363636363636364, recall=0.21212121212121213, fmeasure=0.3181818181818182)),
#  'rouge2': AggregateScore(low=Score(precision=0.23809523809523808, recall=0.07692307692307693, fmeasure=0.11627906976744187), mid=Score(precision=0.23809523809523808, recall=0.07692307692307693, fmeasure=0.11627906976744187), high=Score(precision=0.23809523809523808, recall=0.07692307692307693, fmeasure=0.11627906976744187)),
# ...

# %% [markdown]
# # Eg 5

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


text1 = """Once upon a time, there was a poor but hard-working man named Jack. Jack lived in a small cottage with his mother, and they struggled to make ends meet. Jack's only treasure was a cow that provided them with milk to sell in the market.
One day, Jack traded his cow for a handful of magic beans, which he brought home to his mother. She was furious with him for making such a foolish trade and threw the beans out the window in frustration.
However, overnight, a giant beanstalk grew from the beans, reaching up into the sky. Jack climbed the beanstalk and found a giant's castle in the clouds. The giant, who was away at the time, had a hen that laid golden eggs and a harp that played beautiful music by itself.
Jack stole the hen and the harp and climbed back down the beanstalk. He and his mother were able to sell the golden eggs for a great deal of money, and they lived a happy and comfortable life from then on.
The giant eventually returned and discovered that Jack had stolen from him. In a rage, he climbed down the beanstalk after Jack. Jack, using his wit and bravery, was able to chop down the beanstalk, causing the giant to fall to his death."""
# Input text - to summarize
#text = "story.txt"
#sentences =  read_article(text)
# Tokenizing the text
stopWords = set(stopwords.words("english"))
words = word_tokenize(text1)

# Creating a frequency table to keep the
# score of each word

freqTable = dict()
for word in words:
	word = word.lower()
	if word in stopWords:
		continue
	if word in freqTable:
		freqTable[word] += 1
	else:
		freqTable[word] = 1
sentences = sent_tokenize(text1)
sentenceValue = dict()

for sentence in sentences:
	for word, freq in freqTable.items():
		if word in sentence.lower():
			if sentence in sentenceValue:
				sentenceValue[sentence] += freq
			else:
				sentenceValue[sentence] = freq



sumValues = 0
for sentence in sentenceValue:
	sumValues += sentenceValue[sentence]

# Average value of a sentence from the original text

average = int(sumValues / len(sentenceValue))

# Storing sentences into our summary.
summary = ''
for sentence in sentences:
	if (sentence in sentenceValue) and (sentenceValue[sentence] > (1.2 * average)):
		summary += " " + sentence
print(summary)
# Out:
#  One day, Jack traded his cow for a handful of magic beans, which he brought home to his mother. Jack, using his wit and bravery, was able to chop down the beanstalk, causing the giant to fall to his death.

# %%
rouge = load_metric("rouge")
predictions = [" One day, Jack traded his cow for a handful of magic beans, which he brought home to his mother. Jack, using his wit and bravery, was able to chop down the beanstalk, causing the giant to fall to his death."]
references = ["The story is about a poor man named Jack who trades his cow for magic beans. A beanstalk grows overnight, and Jack climbs it to find a giant's castle in the clouds. He steals the giant's hen and harp, and he and his mother live a happy and comfortable life. The giant eventually comes after Jack, but he uses his wit and bravery to chop down the beanstalk and defeat the giant."]
rouge.compute(predictions=predictions, references=references)
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.575, recall=0.3108108108108108, fmeasure=0.40350877192982454), mid=Score(precision=0.575, recall=0.3108108108108108, fmeasure=0.40350877192982454), high=Score(precision=0.575, recall=0.3108108108108108, fmeasure=0.40350877192982454)),
#  'rouge2': AggregateScore(low=Score(precision=0.3076923076923077, recall=0.1643835616438356, fmeasure=0.21428571428571427), mid=Score(precision=0.3076923076923077, recall=0.1643835616438356, fmeasure=0.21428571428571427), high=Score(precision=0.3076923076923077, recall=0.1643835616438356, fmeasure=0.21428571428571427)),
#  'rougeL': AggregateScore(low=Score(precision=0.525, recall=0.28378378378378377, fmeasure=0.3684210526315789), mid=Score(precision=0.525, recall=0.28378378378378377, fmeasure=0.3684210526315789), high=Score(precision=0.525, recall=0.28378378378378377, fmeasure=0.3684210526315789)),
# ...

# %% [markdown]
# # Eg 6

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize


text1 = """In a far-off kingdom, there lived a prince named Alexander. Alexander was handsome, brave, and kind, but he was also very lonely. He had everything he could ever want, except for someone to share his life with.
One day, Alexander went on a hunting trip and came across a beautiful princess who was being held captive by a fierce dragon. Without hesitation, Alexander rode to the rescue, defeated the dragon, and freed the princess. Her name was Isabella, and she was equally as kind and brave as Alexander.
The two quickly fell in love and got married in a grand ceremony, surrounded by their friends and family. They ruled the kingdom together, ruling with fairness and justice, and their people loved and respected them.
Years passed, and Alexander and Isabella had many children and lived a long and happy life together. When they grew old, they passed their throne to their children, who continued their legacy of kindness and fairness. And so, the kingdom prospered for generations to come, all because of the love and bravery of Alexander and Isabella"""
# Input text - to summarize
#text = "story.txt"
#sentences =  read_article(text)
# Tokenizing the text
stopWords = set(stopwords.words("english"))
words = word_tokenize(text1)

# Creating a frequency table to keep the
# score of each word

freqTable = dict()
for word in words:
	word = word.lower()
	if word in stopWords:
		continue
	if word in freqTable:
		freqTable[word] += 1
	else:
		freqTable[word] = 1
sentences = sent_tokenize(text1)
sentenceValue = dict()

for sentence in sentences:
	for word, freq in freqTable.items():
		if word in sentence.lower():
			if sentence in sentenceValue:
				sentenceValue[sentence] += freq
			else:
				sentenceValue[sentence] = freq



sumValues = 0
for sentence in sentenceValue:
	sumValues += sentenceValue[sentence]

# Average value of a sentence from the original text

average = int(sumValues / len(sentenceValue))

# Storing sentences into our summary.
summary = ''
for sentence in sentences:
	if (sentence in sentenceValue) and (sentenceValue[sentence] > (1.2 * average)):
		summary += " " + sentence
print(summary)
# Out:
#  Years passed, and Alexander and Isabella had many children and lived a long and happy life together.

# %%
rouge = load_metric("rouge")
predictions = [" Years passed, and Alexander and Isabella had many children and lived a long and happy life together. "]
references = ["The story is about a prince named Alexander who rescues a captive princess named Isabella. The two fall in love and get married, ruling the kingdom together with fairness and justice. They live a long and happy life, passing their legacy of kindness and fairness to their children, who continue to prosper the kingdom for generations to come."]
rouge.compute(predictions=predictions, references=references)
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.7058823529411765, recall=0.20689655172413793, fmeasure=0.32), mid=Score(precision=0.7058823529411765, recall=0.20689655172413793, fmeasure=0.32), high=Score(precision=0.7058823529411765, recall=0.20689655172413793, fmeasure=0.32)),
#  'rouge2': AggregateScore(low=Score(precision=0.25, recall=0.07017543859649122, fmeasure=0.1095890410958904), mid=Score(precision=0.25, recall=0.07017543859649122, fmeasure=0.1095890410958904), high=Score(precision=0.25, recall=0.07017543859649122, fmeasure=0.1095890410958904)),
#  'rougeL': AggregateScore(low=Score(precision=0.47058823529411764, recall=0.13793103448275862, fmeasure=0.21333333333333335), mid=Score(precision=0.47058823529411764, recall=0.13793103448275862, fmeasure=0.21333333333333335), high=Score(precision=0.47058823529411764, recall=0.13793103448275862, fmeasure=0.21333333333333335)),
# ...

# %% [markdown]
# # Conlusion
#
# ---
#
#
#
# ---

# %%
from google.colab import files #for uploading file from local machine
uploaded = files.upload()
# Out:
#      <input type="file" id="files-17ae1792-4d48-4267-95f3-b944e83c1130" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-17ae1792-4d48-4267-95f3-b944e83c1130">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('Average - Sheet1.csv')

# %%
df
# Out:
#      Rouge 1    Unnamed: 1 Unnamed: 2  Unnamed: 3       Rouge 2    Unnamed: 5  \
# 0  Precision        Recall   Fmeasure         NaN     Precision        Recall
# 1      0.303          0.47      0.368         NaN         0.058          0.09
# 2      0.473         0.329      0.388         NaN         0.178         0.123
# 3       0.68         0.239      0.354         NaN         0.458         0.157
# 4      0.636         0.212      0.318         NaN         0.238         0.076
# 5      0.575          0.31      0.403         NaN         0.307         0.164
# 6      0.705         0.206       0.32         NaN          0.25          0.07
# 7      0.562  0.2943333333     0.3585         NaN  0.2481666667  0.1133333333
#
#      Unnamed: 6  Unnamed: 7       Rouge L Unnamed: 9   Unnamed: 10  \
# 0      Fmeasure         NaN     Precision     Recall      Fmeasure
# 1         0.071         NaN           0.2       0.31         0.243
# ...
